# %% [markdown]
# ### Introduction to Streamlit
# Streamlit is an open-source app framwork for Machine Learning and Data Science projects. It allows you to create beautiful web applications for your machine learning and data science projects with simple Python scripts.
