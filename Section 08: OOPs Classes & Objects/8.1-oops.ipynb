# %% [markdown]
# ### Classes and Objects
#
# ### 1st Def:
# Object-Oriented Programming (OOP) is a programming paradiagm that uses "objects" to design applications and computer programs. OOP allows for modeling real-world scenarios using classes and objects. This lesson covers the basics of creating classes and objects, including instance variables and methods.
#
# ### 2nd Def:
# OOP is programming style where you organize your code suing classes and objects.
#
# => Instead of just using functions and variables, you group related data and behavior together.
#
# => OOP helps you model real-world things like a car, student, employee, bank account, etc.

# %%
### A class is a blue print fo creating objects. Attributes, methods

class Car:
    pass

audi=Car()
bmw=Car()

print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)

# %%
audi.windows=4
print(audi.windows)
# Out:
# 4

# %%
tata=Car()
tata.doors=4
print(tata.windows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 tata=Car()
#       2 tata.doors=4
# ----> 3 print(tata.windows)
#
# AttributeError: 'Car' object has no attribute 'windows'

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
### Instance Variables and Methods

class Dog:
    ## constructor
    def __init__(self,name,age):
        self.name=name,
        self.age=age

## create objects
dog1=Dog("buddy", 5)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# ...
# ('buddy',)
# 5

# %%
dog2=Dog("Waqar", 28)
print(dog2.name)
print(dog2.age)
# Out:
# ('Waqar',)
# 28

# %%
### Define a class with instance methods
class Dog:
    def __init__(self, name, age):
        self.name=name
        self.age=age

    def bark(self):
        print(f"{self.name} says woof")

dog1=Dog("Buddy",3)
dog1.bark()
dog2=Dog("Lucy",4)
dog2.bark()
# Out:
# Buddy says woof
# Lucy says woof

# %%
### Modeling a Bank Account

## Define a class for bank account
class BankAccount:
    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance

    def deposit(self,amount):
        self.balance+=amount
        print(f"{amount} is deposited. New balance is {self.balance}")

    def withdraw(self, amount):
        if amount>self.balance:
            print("Insufficient funds!")
        else:
            self.balance-=amount
            print(f"{amount} is withdrawn. New balacne is {self.balance}")

    def get_balance(self):
        return self.balance

## create an account

account=BankAccount("Waqar", 5000)
print(account.balance)
# Out:
# 5000

# %%
## Call instance methods
account.deposit(100)
# Out:
# 100 is deposited. New balance is 5100

# %%
account.withdraw(300)
# Out:
# 300 is withdrawn. New balacne is 4800

# %%
print(account.get_balance())
# Out:
# 4800

# %% [markdown]
# ### Conclusion
# Object-Oriented Programming (OOP) allows you to model real-world scenarios using classes and objects. In this lesson, you learned how to create classes and objects, define instance variables and methods, and use them to perform various operations. Understnading these concepts is fundamental to writing effective and maintainable Python code.
