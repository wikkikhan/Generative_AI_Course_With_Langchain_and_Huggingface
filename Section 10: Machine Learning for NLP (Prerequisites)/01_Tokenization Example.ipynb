# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\waqar\anaconda3\lib\site-packages (3.9.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: click in c:\users\waqar\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\waqar\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\waqar\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\waqar\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\waqar\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
corpus="""Hello Welcome, to Waqar's Tokenization, an example of NLP.
Please watch the entire example! to be an expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello Welcome, to Waqar's Tokenization, an example of NLP.
# Please watch the entire example! to be an expert in NLP.

# %%
## Tokenizaiton
## Sentence --> Paragraphs
from nltk.tokenize import sent_tokenize
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\waqar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome, to Waqar's Tokenization, an example of NLP.
# Please watch the entire example!
# to be an expert in NLP.

# %%
## Tokenization
## Paragraph--->words
## Sentence--->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Waqar',
#  "'s",
#  'Tokenization',
#  ',',
#  'an',
#  'example',
#  'of',
#  'NLP',
#  '.',
#  'Please',
#  'watch',
#  'the',
#  'entire',
#  'example',
#  '!',
#  'to',
#  'be',
#  'an',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Waqar', "'s", 'Tokenization', ',', 'an', 'example', 'of', 'NLP', '.']
# ['Please', 'watch', 'the', 'entire', 'example', '!']
# ['to', 'be', 'an', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Waqar',
#  "'",
#  's',
#  'Tokenization',
#  ',',
#  'an',
#  'example',
#  'of',
#  'NLP',
#  '.',
#  'Please',
#  'watch',
#  'the',
#  'entire',
#  'example',
#  '!',
#  'to',
#  'be',
#  'an',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Waqar',
#  "'s",
#  'Tokenization',
#  ',',
#  'an',
#  'example',
#  'of',
#  'NLP.',
#  'Please',
#  'watch',
#  'the',
#  'entire',
#  'example',
#  '!',
#  'to',
#  'be',
#  'an',
#  'expert',
#  'in',
#  'NLP',
#  '.']
